# %% [markdown]
# <a href="https://colab.research.google.com/github/sampak407-dotcom/ramya/blob/main/ex13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
print("print 5 records:",df.head())
print("size of the data set",df.shape)
plt.scatter(df['petal length (cm)'],df['petal width (cm)'])
plt.xlabel('petal length cm')
plt.ylabel('petal width cm')
plt.title('petal length vs petal width')
plt.show()
print('missing vlues in each column:',df.isnull().sum())
print("summary of the data set:",df.describe())
# Out:
# print 5 records:    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# size of the data set (150, 4)
# missing vlues in each column: sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64
# summary of the data set:        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# ...
