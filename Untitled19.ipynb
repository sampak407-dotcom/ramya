# %% [markdown]
# <a href="https://colab.research.google.com/github/sampak407-dotcom/ramya/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
Series_A=[10,20,30,40,50]
Series_B=[40,50,60,70,80]
union=pd.Series(np.union1d(Series_A,Series_B))
intersect=pd.Series(np.intersect1d(Series_A,Series_B))
notcommonseries=union[-union.isin(intersect)]
print(notcommonseries)
# Out:
# 0    10
# 1    20
# 2    30
# 5    60
# 6    70
# 7    80
# dtype: int64

# %%
import pandas as pd
import numpy as np
Series_A=[10,20,30,40,50]
Series_B=[40,50,60,70,80]
union=pd.Series(np.union1d(Series_A,Series_B))
intersect=pd.Series(np.intersect1d(Series_A,Series_B))
notcommonseries=union[-union.isin(intersect)]
print(notcommonseries)
print("largest number in Series_A is:",pd.Series(Series_A).max())
print("smallest number in Series_A is:",pd.Series(Series_A).min())
# Out:
# 0    10
# 1    20
# 2    30
# 5    60
# 6    70
# 7    80
# dtype: int64
# largest number in Series_A is: 50
# smallest number in Series_A is: 10

# %%
import pandas as pd
import numpy as np
Series_A=[10,20,30,40,50]
Series_B=[40,50,60,70,80]
union=pd.Series(np.union1d(Series_A,Series_B))
intersect=pd.Series(np.intersect1d(Series_A,Series_B))
notcommonseries=union[-union.isin(intersect)]
print(notcommonseries)
print("the sum Series_B is:",pd.Series(Series_B).sum())
# Out:
# 0    10
# 1    20
# 2    30
# 5    60
# 6    70
# 7    80
# dtype: int64
# the sum Series_B is: 300

# %%
import pandas as pd
import numpy as np
Series_A=[10,20,30,40,50]
Series_B=[40,50,60,70,80]
union=pd.Series(np.union1d(Series_A,Series_B))
intersect=pd.Series(np.intersect1d(Series_A,Series_B))
notcommonseries=union[-union.isin(intersect)]
print(notcommonseries)
print("the average of Series_A is:",pd.Series(Series_A).mean())
# Out:
# 0    10
# 1    20
# 2    30
# 5    60
# 6    70
# 7    80
# dtype: int64
# the average of Series_A is: 30.0

# %%
import pandas as pd
import numpy as np
Series_A=[10,20,30,40,50]
Series_B=[40,50,60,70,80]
union=pd.Series(np.union1d(Series_A,Series_B))
intersect=pd.Series(np.intersect1d(Series_A,Series_B))
notcommonseries=union[-union.isin(intersect)]
print(notcommonseries)
print("the median of Series_B is:",pd.Series(Series_B).median())
# Out:
# 0    10
# 1    20
# 2    30
# 5    60
# 6    70
# 7    80
# dtype: int64
# the median of Series_B is: 60.0
