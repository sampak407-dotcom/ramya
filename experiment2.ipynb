# %% [markdown]
# <a href="https://colab.research.google.com/github/sampak407-dotcom/ramya/blob/main/experiment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
    'Firstname':['aryan','rohan','riya','yash','siddini'],
    'Lastname':['singh','agarwal','shah','batia','khan'],
    'Type':['full_time employee','return','full_time employee','part_time employee','full_time employee'],
    'Department':['administration','techncal','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,2000,30000]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Firstname Lastname                Type      Department  yoe  salary
# 0     aryan    singh  full_time employee  administration    2   20000
# 1     rohan  agarwal              return        techncal    3    5000
# 2      riya     shah  full_time employee  administration    5   10000
# 3      yash    batia  part_time employee       technical    7    2000
# 4   siddini     khan  full_time employee       technical    6   30000

# %%
import pandas as pd
import numpy as np
data={
    'Firstname':['aryan','rohan','riya','yash','siddini'],
    'Lastname':['singh','agarwal','shah','batia','khan'],
    'Type':['full_time employee','return','full_time employee','part_time employee','full_time employee'],
    'Department':['administration','techncal','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,2000,30000]
}
df=pd.DataFrame(data)
print(df)
table=pd.pivot_table(df,index=['Type','Department'],values='salary',aggfunc=['mean'])
print(table)
table1=pd.pivot_table(df,index=['Type'],values='salary',aggfunc=['sum','mean'])
print(table1)
table2=pd.pivot_table(df,index=['Type'],values='salary',aggfunc=['count'])
print(table2)
table3=pd.pivot_table(df,index=['Type'],values='salary',aggfunc=['std'])
print(table3)
# Out:
#   Firstname Lastname                Type      Department  yoe  salary
# 0     aryan    singh  full_time employee  administration    2   20000
# 1     rohan  agarwal              return        techncal    3    5000
# 2      riya     shah  full_time employee  administration    5   10000
# 3      yash    batia  part_time employee       technical    7    2000
# 4   siddini     khan  full_time employee       technical    6   30000
#                                       mean
#                                     salary
# Type               Department
# full_time employee administration  15000.0
#                    technical       30000.0
# part_time employee technical        2000.0
# return             techncal         5000.0
#                       sum     mean
#                    salary   salary
# Type
# full_time employee  60000  20000.0
# part_time employee   2000   2000.0
# return               5000   5000.0
#                     count
#                    salary
# Type
# ...
