# %% [markdown]
# <a href="https://colab.research.google.com/github/sampak407-dotcom/ramya/blob/main/Untitled36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
cars_df=np.read_csv('/content/mtcars (8).csv')
print(cars_df)
a=plt.scatter(cars_df['mpg'],cars_df['wt'],marker='*')
print(a)
plt.xlabel('mpg')
plt.ylabel('wt')
plt.title('relationshipbetweentheweightofthecarandmpg')
plt.show()
trans=cars_df['am'].value_counts()
print(trans)
trans.plt.bar()
plt.xlabel('transmission')
plt.ylabel('barplottocheckfrequencydistributionoftransmissiontypeofcars')
plt.show()
cars_df=['mpg'].plot(kind='box')
plt.xlabel('mpg')
plt.title('boxandwhiskerplottoMPG')
plt.show()
minvalue=np.min(cars_df('mpg'))
q1=np.percentile(cars_df['mpg'],25)
median=np.meadin(cars_df['mpg'])
q3=np.percentile(cars_df['mpg'],75)
maxvalue=np.max(cars_df['mpg'])
print('minimumvalue:',minvalue)
print('Q1:',q1)
print('median:',median)
print('Q3:',q3)
print('maximumvalue:',maxvalue)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_735/1739184653.py in <cell line: 0>()
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 4 cars_df=np.read_csv('/content/mtcars (8).csv')
#       5 print(cars_df)
#       6 a=plt.scatter(cars_df['mpg'],cars_df['wt'],marker='*')
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     408             return char.chararray
#     409
# --> 410         raise AttributeError("module {!r} has no attribute "
#     411                              "{!r}".format(__name__, attr))
#     412
#
# AttributeError: module 'numpy' has no attribute 'read_csv'
