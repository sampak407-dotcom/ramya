# %% [markdown]
# <a href="https://colab.research.google.com/github/sampak407-dotcom/ramya/blob/main/exp12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,mean_absolute_error
df=pd.read_csv('/content/boston_housing (3).csv')
print(df)
print(df.info())
print(df.head())
plt.scatter(df.rm,df.lstat,color='gold',marker='*')
plt.xlabel('rm')
plt.ylabel('lstat')
plt.title('Scatterplot')
plt.show()
x=df.drop('lstat',axis=1)
print(x)
# Out:
#         crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  Price
# 0    0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98   24.0
# 1    0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14   21.6
# 2    0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03   34.7
# 3    0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94   33.4
# 4    0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33   36.2
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...    ...
# 501  0.06263   0.0  11.93     0  0.573  ...  273     21.0  391.99   9.67   22.4
# 502  0.04527   0.0  11.93     0  0.573  ...  273     21.0  396.90   9.08   20.6
# 503  0.06076   0.0  11.93     0  0.573  ...  273     21.0  396.90   5.64   23.9
# 504  0.10959   0.0  11.93     0  0.573  ...  273     21.0  393.45   6.48   22.0
# 505  0.04741   0.0  11.93     0  0.573  ...  273     21.0  396.90   7.88   11.9
#
# ...
